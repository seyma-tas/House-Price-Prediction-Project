# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib
import seaborn as sns

from scipy import stats
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

sns.set(style='darkgrid')
# Out:
# Using matplotlib backend: MacOSX

# %%
df=pd.read_csv('king_county_dataset_cleaned2.csv')

# %%
df.head()
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1     538000.0         3       2.25         2570      7242     2.0
# 35    696000.0         3       2.50         2300      3060     1.5
# 95    905000.0         4       2.50         3300     10250     1.0
# 103  1090000.0         3       2.50         2920      8113     2.0
# 125  1450000.0         4       2.75         2750     17789     1.5
#
#      waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 1           0.0   0.0          3      7        2170          400.0      1951
# 35          0.0   0.0          3      8        1510          790.0      1930
# 95          0.0   0.0          3      7        2390          910.0      1946
# 103         0.0   0.0          3      8        2920            0.0      1950
# 125         0.0   0.0          3      8        1980          770.0      1914
#
#      yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
type(df['yr_renovated'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 1 to 20943
# Data columns (total 20 columns):
# price            500 non-null float64
# bedrooms         500 non-null int64
# bathrooms        500 non-null float64
# sqft_living      500 non-null int64
# sqft_lot         500 non-null int64
# floors           500 non-null float64
# waterfront       500 non-null float64
# view             500 non-null float64
# condition        500 non-null int64
# grade            500 non-null int64
# sqft_above       500 non-null int64
# sqft_basement    500 non-null float64
# yr_built         500 non-null int64
# yr_renovated     500 non-null float64
# zipcode          500 non-null int64
# lat              500 non-null float64
# long             500 non-null float64
# sqft_living15    500 non-null int64
# sqft_lot15       500 non-null int64
# sale_month       500 non-null int64
# dtypes: float64(9), int64(11)
# memory usage: 82.0 KB

# %%
df.yr_renovated=df[df.yr_renovated != 0]

# %%
df.yr_renovated.unique()
# Out:
# array([2002., 2010., 2013., 2005., 2003., 2014., 2011., 2004., 2007.,
#        2006., 2001., 2009., 2015., 2008., 2012.])

# %%
df.yr_renovated.head()
# Out:
# 0         NaN
# 1    538000.0
# 2         NaN
# 3         NaN
# 4         NaN
# Name: yr_renovated, dtype: float64

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0         0.0
# 1  538000.0         3       2.25         2570      7242     2.0         0.0
# 2  180000.0         2       1.00          770     10000     1.0         0.0
# 3  604000.0         4       3.00         1960      5000     1.0         0.0
# 4  510000.0         3       2.00         1680      8080     1.0         0.0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0   0.0          3      7        1180            0.0  221900.0           NaN
# 1   0.0          3      7        2170          400.0  538000.0      538000.0
# 2   0.0          3      6         770            0.0  180000.0           NaN
# 3   0.0          5      7        1050          910.0  604000.0           NaN
# 4   0.0          3      8        1680            0.0  510000.0           NaN
#
# ...

# %%
fig = plt.figure(figsize = (20,8));
fig = sns.boxplot(x='yr_renovated', y='price', data=df, showfliers = False);
plt.title('Prices of Houses Sold in King County by Zip Code',fontsize=18);
plt.xlabel("Zip Code", fontsize=18);
plt.xticks(rotation=90);
plt.ylabel('Sale Price, $', fontsize=18);
plt.show();

# %%
fig = sns.jointplot(x='sale_month', y='price', data=df,height=9);

# %%
df.price=df[df.price != 0]

# %%
sns.distplot(df['sale_month'],norm_hist=True,color='r',kde_kws={"color": "k", "lw": 3, "label": "KDE"})

# %%
fig = plt.figure(figsize = (20,8));
fig =sns.distplot(df['sale_month'],norm_hist=True,color='r',kde_kws={"color": "k", "lw": 3, "label": "KDE"})
plt.title('The Distribution of Houses Sold Every Month',fontsize=18);
plt.xlabel("Sale Month", fontsize=18);
plt.ylabel('Sale Number', fontsize=18);
plt.show();

# %%
fig = plt.figure(figsize = (20,8));
fig =sns.jointplot(x='sqft_living',y='price',data= df,kind='reg',height=8)
plt.show();

# %%
fig = sns.jointplot(x='lat', y='price', data=df,height=9,kind='reg');

# %%
fig = sns.jointplot(x='long', y='price', data=df,height=9,kind='reg');

# %%
x_cols = ['grade_10', 'grade_11', 'bathrooms', 'sqft_above', 'sqft_living15', 'sqft_basement', 'grade_9', 'grade_8', 'zipcode_98023', 'zipcode_98004', 'grade_12', 'grade_7', 'zipcode_98003', 'zipcode_98092', 'waterfront_1_0', 'zipcode_98058', 'zipcode_98002', 'zipcode_98032', 'zipcode_98178', 'grade_13', 'zipcode_98033', 'zipcode_98040', 'zipcode_98112', 'zipcode_98039', 'zipcode_98115', 'zipcode_98103', 'zipcode_98117', 'zipcode_98199', 'zipcode_98105', 'zipcode_98119', 'zipcode_98107', 'zipcode_98116', 'zipcode_98109', 'zipcode_98122', 'view_4_0', 'zipcode_98102', 'sqft_living', 'zipcode_98006', 'zipcode_98052', 'zipcode_98136', 'zipcode_98144', 'sqft_lot', 'zipcode_98008', 'zipcode_98005', 'view_3_0', 'zipcode_98053', 'condition_5', 'zipcode_98126', 'zipcode_98125', 'zipcode_98029', 'zipcode_98034', 'zipcode_98177', 'zipcode_98007', 'zipcode_98074', 'zipcode_98075', 'sale_month_4', 'zipcode_98027', 'zipcode_98118', 'zipcode_98133', 'view_2_0', 'zipcode_98072', 'zipcode_98155', 'condition_4', 'condition_3', 'sale_month_3', 'view_1_0', 'zipcode_98011', 'zipcode_98065', 'zipcode_98028', 'zipcode_98077', 'zipcode_98106', 'yr_renovated', 'zipcode_98108', 'zipcode_98059', 'zipcode_98056', 'zipcode_98024', 'zipcode_98045', 'zipcode_98166', 'zipcode_98146', 'zipcode_98019', 'zipcode_98070', 'zipcode_98014', 'floors_3_0', 'zipcode_98038', 'zipcode_98010', 'zipcode_98055', 'grade_5', 'sqft_lot15', 'bedrooms_7', 'bedrooms_2', 'sale_month_2', 'zipcode_98148', 'sale_month_5', 'condition_2', 'bedrooms_6', 'floors_2_0', 'bedrooms_5', 'zipcode_98168', 'zipcode_98188', 'bedrooms_9']

# %%
x_cols.sort()

# %%
x_cols
# Out:
# ['bathrooms',
#  'bedrooms_2',
#  'bedrooms_5',
#  'bedrooms_6',
#  'bedrooms_7',
#  'bedrooms_9',
#  'condition_2',
#  'condition_3',
#  'condition_4',
#  'condition_5',
#  'floors_2_0',
#  'floors_3_0',
#  'grade_10',
#  'grade_11',
#  'grade_12',
#  'grade_13',
#  'grade_5',
#  'grade_7',
#  'grade_8',
#  'grade_9',
#  'sale_month_2',
#  'sale_month_3',
#  'sale_month_4',
#  'sale_month_5',
#  'sqft_above',
#  'sqft_basement',
#  'sqft_living',
#  'sqft_living15',
#  'sqft_lot',
#  'sqft_lot15',
#  'view_1_0',
#  'view_2_0',
#  'view_3_0',
#  'view_4_0',
#  'waterfront_1_0',
#  'yr_renovated',
#  'zipcode_98002',
#  'zipcode_98003',
#  'zipcode_98004',
#  'zipcode_98005',
#  'zipcode_98006',
#  'zipcode_98007',
#  'zipcode_98008',
#  'zipcode_98010',
#  'zipcode_98011',
#  'zipcode_98014',
#  'zipcode_98019',
#  'zipcode_98023',
#  'zipcode_98024',
#  'zipcode_98027',
#  'zipcode_98028',
#  'zipcode_98029',
#  'zipcode_98032',
#  'zipcode_98033',
#  'zipcode_98034',
# ...

# %%
refinement=['sqft_living', 'sqft_living15', 'zipcode_98004', 'zipcode_98023', 'view_4_0', 'grade_7', 'grade_6', 'grade_8', 
            'grade_5', 'grade_9', 'zipcode_98003', 'zipcode_98092', 'zipcode_98058', 'zipcode_98038', 'zipcode_98002', 
            'zipcode_98032', 'bathrooms', 'zipcode_98039', 'zipcode_98040', 'zipcode_98033', 'zipcode_98112', 'zipcode_98115',
            'zipcode_98103', 'zipcode_98117', 'zipcode_98199', 'zipcode_98105', 'zipcode_98119', 'zipcode_98107', 'zipcode_98109',
            'waterfront_1_0', 'zipcode_98116', 'zipcode_98122', 'zipcode_98102', 'zipcode_98006', 'zipcode_98052', 'zipcode_98136',
            'zipcode_98144', 'sqft_lot', 'zipcode_98008', 'zipcode_98005', 'grade_4', 'zipcode_98053', 'view_3_0', 'zipcode_98029', 
            'zipcode_98126', 'zipcode_98125', 'zipcode_98034', 'zipcode_98177', 'zipcode_98007', 'condition_5', 'sale_month_4', 'zipcode_98074', 'zipcode_98075', 'grade_10', 'zipcode_98027', 'view_2_0', 'sqft_above', 'zipcode_98133', 'zipcode_98118', 'zipcode_98072', 'zipcode_98155', 'condition_4', 'condition_3', 'view_1_0', 'sale_month_3', 'zipcode_98011', 'zipcode_98065', 'zipcode_98028', 'zipcode_98077', 'zipcode_98106', 'yr_renovated', 'zipcode_98108', 'zipcode_98059', 'zipcode_98056', 'zipcode_98024', 'grade_11', 'floors_3_0', 'zipcode_98166', 'zipcode_98045', 'zipcode_98146', 'zipcode_98019', 'zipcode_98014', 'zipcode_98070', 'zipcode_98010', 'zipcode_98178', 'zipcode_98055', 'sqft_lot15', 'sqft_basement', 'bedrooms_7', 'bedrooms_2', 'zipcode_98148', 'grade_13', 'sale_month_2', 'sale_month_5', 
            'condition_2', 'bedrooms_6', 'floors_2_0', 'bedrooms_5', 'zipcode_98168', 'zipcode_98188', 'bedrooms_9']

# %%
refinement.sort()

# %%
refinement
# Out:
# ['bathrooms',
#  'bedrooms_2',
#  'bedrooms_5',
#  'bedrooms_6',
#  'bedrooms_7',
#  'bedrooms_9',
#  'condition_2',
#  'condition_3',
#  'condition_4',
#  'condition_5',
#  'floors_2_0',
#  'floors_3_0',
#  'grade_10',
#  'grade_11',
#  'grade_13',
#  'grade_4',
#  'grade_5',
#  'grade_6',
#  'grade_7',
#  'grade_8',
#  'grade_9',
#  'sale_month_2',
#  'sale_month_3',
#  'sale_month_4',
#  'sale_month_5',
#  'sqft_above',
#  'sqft_basement',
#  'sqft_living',
#  'sqft_living15',
#  'sqft_lot',
#  'sqft_lot15',
#  'view_1_0',
#  'view_2_0',
#  'view_3_0',
#  'view_4_0',
#  'waterfront_1_0',
#  'yr_renovated',
#  'zipcode_98002',
#  'zipcode_98003',
#  'zipcode_98004',
#  'zipcode_98005',
#  'zipcode_98006',
#  'zipcode_98007',
#  'zipcode_98008',
#  'zipcode_98010',
#  'zipcode_98011',
#  'zipcode_98014',
#  'zipcode_98019',
#  'zipcode_98023',
#  'zipcode_98024',
#  'zipcode_98027',
#  'zipcode_98028',
#  'zipcode_98029',
#  'zipcode_98032',
#  'zipcode_98033',
#  'zipcode_98034',
# ...

# %%
model=['grade_10', 'grade_11', 'bathrooms', 'sqft_above', 'sqft_living15', 'sqft_basement', 'grade_9', 'grade_8', 'zipcode_98023', 'zipcode_98004', 'grade_12', 'grade_7', 'zipcode_98003', 'zipcode_98092', 'waterfront_1_0', 'zipcode_98058', 'zipcode_98002', 'zipcode_98032', 'zipcode_98178', 'grade_13', 'zipcode_98033', 'zipcode_98040', 'zipcode_98112', 'zipcode_98039', 'zipcode_98115', 'zipcode_98103', 'zipcode_98117', 'zipcode_98199', 'zipcode_98105', 'zipcode_98119', 'zipcode_98107', 'zipcode_98116', 'zipcode_98109', 'zipcode_98122', 'view_4_0', 'zipcode_98102', 'sqft_living', 'zipcode_98006', 'zipcode_98052', 'zipcode_98136', 'zipcode_98144', 'sqft_lot', 'zipcode_98008', 'zipcode_98005', 'view_3_0', 'zipcode_98053', 'condition_5', 'zipcode_98126', 'zipcode_98125', 'zipcode_98029', 'zipcode_98034', 'zipcode_98177', 'zipcode_98007', 'zipcode_98074', 'zipcode_98075', 'sale_month_4', 'zipcode_98027', 'zipcode_98118', 'zipcode_98133', 'view_2_0', 'zipcode_98072', 'zipcode_98155', 'condition_4', 'condition_3', 'sale_month_3', 'view_1_0', 'zipcode_98011', 'zipcode_98065', 'zipcode_98028', 'zipcode_98077', 'zipcode_98106', 'yr_renovated', 'zipcode_98108', 'zipcode_98059', 'zipcode_98056', 'zipcode_98024', 'zipcode_98045', 'zipcode_98166', 'zipcode_98146', 'zipcode_98019', 'zipcode_98070', 'zipcode_98014', 'floors_3_0', 'zipcode_98038', 'zipcode_98010', 'zipcode_98055', 'grade_5', 'sqft_lot15', 'bedrooms_7', 'bedrooms_2', 'sale_month_2', 'zipcode_98148', 'sale_month_5', 'condition_2', 'bedrooms_6', 'floors_2_0', 'bedrooms_5', 'zipcode_98168', 'zipcode_98188', 'bedrooms_9']

# %%
model.sort()

# %%
model
# Out:
# ['bathrooms',
#  'bedrooms_2',
#  'bedrooms_5',
#  'bedrooms_6',
#  'bedrooms_7',
#  'bedrooms_9',
#  'condition_2',
#  'condition_3',
#  'condition_4',
#  'condition_5',
#  'floors_2_0',
#  'floors_3_0',
#  'grade_10',
#  'grade_11',
#  'grade_12',
#  'grade_13',
#  'grade_5',
#  'grade_7',
#  'grade_8',
#  'grade_9',
#  'sale_month_2',
#  'sale_month_3',
#  'sale_month_4',
#  'sale_month_5',
#  'sqft_above',
#  'sqft_basement',
#  'sqft_living',
#  'sqft_living15',
#  'sqft_lot',
#  'sqft_lot15',
#  'view_1_0',
#  'view_2_0',
#  'view_3_0',
#  'view_4_0',
#  'waterfront_1_0',
#  'yr_renovated',
#  'zipcode_98002',
#  'zipcode_98003',
#  'zipcode_98004',
#  'zipcode_98005',
#  'zipcode_98006',
#  'zipcode_98007',
#  'zipcode_98008',
#  'zipcode_98010',
#  'zipcode_98011',
#  'zipcode_98014',
#  'zipcode_98019',
#  'zipcode_98023',
#  'zipcode_98024',
#  'zipcode_98027',
#  'zipcode_98028',
#  'zipcode_98029',
#  'zipcode_98032',
#  'zipcode_98033',
#  'zipcode_98034',
# ...
